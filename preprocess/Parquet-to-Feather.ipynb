# %%
import numpy as np
import pandas as pd
import pyarrow.feather as feather

LOCAL_PATH = '../input'

# %%
for i in range(4):
    df = pd.read_parquet(LOCAL_PATH+'/train_image_data_{}.parquet'.format(i))
    feather.write_feather(df, LOCAL_PATH+'/parquet-to-feather-no-{}/train_image_data_{}.feather'.format(i,i))
